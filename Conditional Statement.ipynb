# %% [markdown]
# # ***Conditional Statement***
#     - if
#     - if - elif
#     - if - else
#     - if - elif - else
#     - Nested if
#     - shorthand if else / One line if else

# %%
if "rain":
    print("Bring Umbrella")
# Out:
# Bring Umbrella

# %%
y = input("Enter todays weather ?")
if y:
    print("Bring Umbrella")
# Out:
# Enter todays weather ? sunny
# Bring Umbrella

# %%
y = input("Enter todays weather ?")
if y:
    print("Bring Umbrella")
# Out:
# Enter todays weather ? 10
# Bring Umbrella

# %%
y = input("Enter todays weather ?")
if y:
    print("Bring Umbrella")
# Out:
# Enter todays weather ? 0
# Bring Umbrella

# %%
y = input("Enter todays weather ?")
if y:
    print("Bring Umbrella")
# Out:
# Enter todays weather ?

# %% [markdown]
# ## "Empty object"
# - False
# - None
# - list()
# - str()
# - set()
# - dict()
# - tuple()
# - 0
# - None

# %%
y = input("Enter todays weather ?")
print(type(y))
if y:
    print("Bring Umbrella")
# Out:
# Enter todays weather ? 0
# <class 'str'>
# Bring Umbrella

# %%
y = int(input("Enter todays weather ?"))
print(type(y))
if y:
    print("Bring Umbrella")
# Out:
# Enter todays weather ? 0
# <class 'int'>

# %%
name = input("Enter your name")
if name == "simran":
    print(f"welcome {name}")
else:
    print("Goodbye")
# Out:
# Enter your name rohan
# Goodbye

# %%
name = input("Enter your name")
if name == "simran":
    print(f"welcome {name}")
else:
    print("Goodbye")
# Out:
# Enter your name simran
# welcome simran

# %%
name = input("Enter your name")
if name == "simran":
    print(f"welcome {name}")
else:
    print("Goodbye")
print("bye")  # independent statement
print("jao bhai")  # independent statement
# Out:
# Enter your name simran
# welcome simran
# bye
# jao bhai

# %%
name = input("Enter your name")

if name == "simran":
    print(f"welcome {name}")
else:
    print("Goodbye")
    
print("bye")
print("jao bhai")
# Out:
# Enter your name ayan
# Goodbye
# bye
# jao bhai

# %%
ls = ["rohan" , "aman" , "arjun" , "tanvi"]
ls
# Out:
# ['rohan', 'aman', 'arjun', 'tanvi']

# %%
name = input("enter your name")
if name == "mohit":
    print("hello")

elif name == "rohan":
    print("bye")

elif name == "aryan":
    print("goodbye")

else:
    print("ok bye")
# Out:
# enter your name aman
# ok bye

# %%
name = input("enter your name")
if name == "mohit":
    print("hello")

elif name == "rohan":
    print("bye")

elif name == "aryan":
    print("goodbye")

else:
    print("ok bye")
# Out:
# enter your name
# ok bye

# %%
name = input("enter your name")
if name == "mohit":
    print("hello")

elif name == "rohan":
    print("bye")

elif name == "aryan":
    print("goodbye")

else:
    print("ok bye")
# Out:
# enter your name aryan
# goodbye

# %%
ls
# Out:
# ['rohan', 'aman', 'arjun', 'tanvi']

# %%
if [[]]:
    print("hi")
else:
    print("bye")
# Out:
# hi

# %%
len([[]])
# Out:
# 1

# %%
if []:
    print("hi")
else:
    print("bye")
# Out:
# bye

# %%
bool([[]])
# Out:
# True

# %%
ls
# Out:
# ['rohan', 'aman', 'arjun', 'tanvi']

# %%
if ls.sort():    # if None: >>> False
    print(ls)
else:
    print("bye")
# Out:
# bye

# %%
ls
# Out:
# ['aman', 'arjun', 'rohan', 'tanvi']

# %%
print(ls.sort())
# Out:
# None

# %%
ls
# Out:
# ['aman', 'arjun', 'rohan', 'tanvi']

# %%
if ls.pop():
    print(ls)
else:
    print("bye")

# %%
a = ["rohan" , "Aman" , "Arjun"]

# %%
a
# Out:
# ['rohan', 'Aman', 'Arjun']

# %%
print(a.sort())
# Out:
# None

# %%
a
# Out:
# ['Aman', 'Arjun', 'rohan']

# %%
ls.sort()

# %%
ls
# Out:
# ['aman', 'arjun', 'rohan', 'tanvi']

# %%
if ls.pop():  # ans > Tanvi > if "Tanvi"
    print(ls)
else:
    print("bye")
# Out:
# ['aman', 'arjun', 'rohan']

# %%
password = input("Enter enter your password...")

if password == "simran" or "aryan":
    print("Welcome to the account")
else:
    print("Invalid Credentials..")
# Out:
# Enter enter your password... simran
# Welcome to the account

# %%
password = input("Enter enter your password...")

if password == "simran" or "aryan":
    print("Welcome to the account")
else:
    print("Invalid Credentials..")
# Out:
# Enter enter your password... chitransh
# Welcome to the account

# %%
if "chitransh"

# %%
password = input("Enter enter your password...")

if password == "simran" or password == "aryan":
    print("Welcome to the account")
else:
    print("Invalid Credentials..")
# Out:
# Enter enter your password... aryan
# Welcome to the account

# %%
password = input("Enter enter your password...")

if password in ("simran" ,"aryan"):
    print("Welcome to the account")
else:
    print("Invalid Credentials..")
# Out:
# Enter enter your password... aryan
# Welcome to the account

# %%
ls
# Out:
# ['aman', 'arjun', 'rohan']

# %%
password = input("Enter enter your password...")

if password == ("simran" or "aryan"):
    print("Welcome to the account")
else:
    print("Invalid Credentials..")
# Out:
# Enter enter your password... aryan
# Invalid Credentials..

# %%
"aryan" == ("simran" or "aryan")
# Out:
# False

# %%
"simran" or "aryan"

# %%
a = ("simran" and "aryan")

# %%
print(a)
# Out:
# aryan

# %%
("azyan" and "aryan")
# Out:
# 'aryan'

# %%
a
# Out:
# 'aryanzzz'

# %%
a = ("aryanzzz" or "aryandsdasdaswdqwsdqw")

# %%
a
# Out:
# 'aryanzzz'

# %%
("azzzzzyan" and "aryan")
# Out:
# 'aryan'

# %%
("rohan" and [])
# Out:
# []

# %%
("aman" or 0)
# Out:
# 'aman'

# %%
(0 or "aman")
# Out:
# 'aman'

# %%
("azzzzzyan" and [])
# Out:
# []

# %%
([] and [])
# Out:
# []

# %%
("rohan" and "aman" and "rohan" and "chitransh")
# Out:
# 'chitransh'

# %%
week no. > input
1 > mon
2 > tue

# %%
number = int(input("Enter Your Number"))
if number == 1:
    print("Mon")
elif number == 2:
    print("Tue")
elif number == 3:
    print("Wed")
elif number == 4:
    print("Thur")
elif number == 5:
    print("Fri")
elif number == 6:
    print("Sat")
elif number == 7:
    print("sun")
else:
    print("Invalid Input")
# Out:
# Enter Your Number 1
# Mon

# %% [markdown]
# ## Positive , negative , neautral
# ## odd even
