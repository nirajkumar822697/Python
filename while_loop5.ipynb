# %%
import random

# %%
computer_guess = random.randint(1,50)
computer_guess
# Out:
# 36

# %%
i=1
while(i<=5):
    num = int(input(f"Guess a number {i}: "))
    if num>=1 and num<=50:
        
        if num == computer_guess:
            print("Congrates you win 7cr")
            break
        elif num<computer_guess:
            print("Please guess a big number")
        elif num >computer_guess:
            print("please guess a small number")
    else:
        print("Think in limit 1 to 50")
        continue
        
    i+=1
else:
    print("You are looser!")
# Out:
# Guess a number 1:  12
# Please guess a big number
# Guess a number 2:  20
# Please guess a big number
# Guess a number 3:  30
# Please guess a big number
# Guess a number 4:  40
# please guess a small number
# Guess a number 5:  35
# Please guess a big number
# You are looser!

# %%
ls =[['rohan','aman'],['aryan','alok'],['niraj','manish']]

# %%
i=0
while(i<len(ls)):
    print(ls[i])
    j=0
    while(j<len(ls[i])):
        print(ls[i][j])
        j+=1
    i+=1
# Out:
# ['rohan', 'aman']
# rohan
# aman
# ['aryan', 'alok']
# aryan
# alok
# ['niraj', 'manish']
# niraj
# manish
