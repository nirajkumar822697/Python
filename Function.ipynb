# %%
def add( a,b):
    print(a+b)
add(2,3)
# Out:
# 5

# %%
def check():
    a = int(input("Enter a number:"))
    if a%2==0:
        print("even")
    else:
        print("odd")

# %%
check()
# Out:
# Enter a number: 11
# odd

# %%
ls = [100, 10, 20, 30, 10, 200, 10, 20]
ls
# Out:
# [100, 10, 20, 30, 10, 200, 10, 20]

# %%
mx=0
for i in ls:
    if mx<i:
        mx=i
print(mx)
# Out:
# 200

# %%
mx=100
for i in ls:
    if mx>i:
        mx=i
print(mx)
# Out:
# 10

# %%
tp =()
size =int(input("Enter how many element insert:"))
i=1
while(i<=size):
    value =int(input(f"Enter value of {i} element:"))
    tp=tp+(value,)
    i+=1
print(tp)
# Out:
# Enter how many element insert: 5
# Enter value of 1 element: 3
# Enter value of 2 element: 3
# Enter value of 3 element: 4
# Enter value of 4 element: 6
# Enter value of 5 element: 7
# (3, 3, 4, 6, 7)

# %%
num = int(input("Enter a number"))
rem=0
count=0
while(num>0):
    rem= rem%10
    count+=1
    num=num//10
print(count)
# Out:
# Enter a number 234567
# 6

# %%
234567//10
# Out:
# 23456
