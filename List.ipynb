# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
marks = [20,25,96,76,99,100]

# %%
marks.append(10)
marks
# Out:
# [20, 25, 96, 76, 99, 100, 10]

# %%
marks.clear()
marks
# Out:
# []

# %%
mark = marks.copy()

# %%
mark
# Out:
# [20, 25, 96, 76, 99, 100, 10]

# %%
marks
# Out:
# [20, 25, 96, 76, 99, 100, 10]

# %%
marks.count(20)
# Out:
# 1

# %%
marks.index(25)
# Out:
# 1

# %%
marks.extend([20])
marks
# Out:
# [20, 25, 96, 76, 99, 100, 10, 20]

# %%
marks.sort()
marks
# Out:
# [10, 20, 20, 25, 76, 96, 99, 100]

# %%
a = " this is the first  program "
n= a.split()

# %%
" ".join(n)
# Out:
# 'this is the first program'

# %%
"*".join(n)
# Out:
# 'this*is*the*first*program'

# %% [markdown]
# # Indexing
#  - position of an Element

# %%
name = "PYTHON PROGRAMMING"

# %%
print(name[0])
# Out:
# P

# %%
print(name[0::])
# Out:
# PYTHON PROGRAMMING

# %%
print(name[::-1])
# Out:
# GNIMMARGORP NOHTYP

# %% [markdown]
# # slicing
#  - extracting a portion from the object

# %%
print(name[0:4:])
# Out:
# PYTH

# %%
print(name[::2])
# Out:
# PTO RGAMN

# %%
print(name[2:8:1])
# Out:
# THON P

# %% [markdown]
# In the below you not give the step here by default step =1 then  next=-1+1=0 this is wrong

# %%
print(name[-1:-5:])

# %% [markdown]
#  this is right

# %%
print(name[-1:-5:-1])
# Out:
# GNIM

# %% [markdown]
# #  List
#  - collection of multiple data
#  - create by []
#  - ordered

# %%
names = ["manish", "Niraj", "Jai"]
names
# Out:
# ['manish', 'Niraj', 'Jai']

# %%
marks
# Out:
# [10, 20, 20, 25, 76, 96, 99, 100]

# %%
mark
# Out:
# [20, 25, 96, 76, 99, 100, 10]

# %%
names[-2]
# Out:
# 'Niraj'

# %%
names
# Out:
# ['manish', 'Niraj', 'Jai']

# %%
names.append("sir")
names
# Out:
# ['manish', 'Niraj', 'Jai', 'sir']

# %%
x = [1,2,3]
x.append(4)
x.append(5)

# %%
len(x)
# Out:
# 5

# %%
x = [1,2,3]
x.append([4,5])

# %%
x
# Out:
# [1, 2, 3, [4, 5]]

# %%
x = [1,2,3]
x.extend([4,5])

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
len(x)
# Out:
# 5

# %%
x = [1,2,3]
y=x.copy()
y.append(4)
print(len(x),len(y))
# Out:
# 3 4

# %%
int("10") + float("5.5")
# Out:
# 15.5

# %%
type(192.56j)
# Out:
# complex

# %%
type("‘10’")
# Out:
# str

# %% [markdown]
# # Pratice Assignment

# %%
string = "   Python Programming   "

# %%
string.split()
# Out:
# ['Python', 'Programming']

# %%
string.strip()
# Out:
# 'Python Programming'

# %%
string.title()
# Out:
# '   Python Programming   '

# %%
string.replace("Python","Java")
# Out:
# '   Java Programming   '

# %%
s = " PyThOn ProGRamming "

# %%
s.strip()
# Out:
# 'PyThOn ProGRamming'

# %%
s.lower()
# Out:
# ' python programming '

# %%
s.title()
# Out:
# ' Python Programming '

# %%
text = "I love Python, Python is easy"

# %%
text.index("Python")
# Out:
# 7

# %%
text.endswith("easy")
# Out:
# True

# %%
data = "apple,banana,mango,grape"

# %%
store =data.split(",")

# %%
store
# Out:
# ['apple', 'banana', 'mango', 'grape']

# %%
result = "|".join(store)

# %%
result
# Out:
# 'apple|banana|mango|grape'

# %%
s = "ABC123!@#"

# %%
s.isalnum()
# Out:
# False

# %%
s.isdigit()
# Out:
# False

# %%
s.count("A")
# Out:
# 1

# %%
digits = s[3:6]

# %%
len(digits)
# Out:
# 3

# %%
symbol = s[6::]

# %%
len(symbol)
# Out:
# 3

# %%
filename = "report_2024_final.txt"

# %%
filename[7:11]
# Out:
# '2024'

# %%
filename.removesuffix(".txt")
# Out:
# 'report_2024_final'

# %%
word = "RaceCar"

# %%
word == word[::-1]
# Out:
# False

# %%
word =="RaceCar"
# Out:
# True

# %%
datetime_str = "2025-05-10 14:30:00"    #Date: 10/05/2025, Time: 14:30

# %%
date = datetime_str[0:10]

# %%
date
# Out:
# '2025-05-10'

# %%
print(date.replace("_","/"))
# Out:
# 2025-05-10

# %%
print(datetime_str[11:16])
# Out:
# 14:30
