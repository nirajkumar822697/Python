# %% [markdown]
# ### 1. Write a Python program to check whether a number is negative, positive or zero.

# %%
num = int(input("Enter a number: "))
if num<0:
    print(f"{num} is a negative number")
elif num>0:
    print(f"{num} is a positive  number")
else:
     print(f"{num} is a zero  ")
# Out:
# Enter a number:  0
# 0 is a zero

# %% [markdown]
# ### 2.Accept a password. Print "Access Granted" if it matches a predefined value; else "Access Denied".

# %%
password = "Nir123"
passw = input("Enter the password: ")
if  password ==passw:
    print("Access")
# Out:
# Enter the password:  Niraj@123
# Access

# %% [markdown]
# ### 3.Determine if a given year is a century year (divisible by 100).

# %%
year = int(input("Enter the year: "))
if year % 100==0:
    print("century year")
else:
    print("Not century year")
# Out:
# Enter the year:  580
# Not century year

# %% [markdown]
# ### 4. Write a Python program that accepts a month number (from 1 to 12) as input and prints the season based on the month.
#    - Conditions:
#
#       1.  12, 1, 2 → Winter
#
#       2.  3, 4, 5 → Spring
#
#       3.  6, 7, 8 → Summer
#
#       4.  9, 10, 11 → Autumn
#
#        Any other number → "Invalid month number"

# %%
month = int(input("Enter the month : "))
if  month == 1 or month == 2 or month == 12:
    print("Winter")
elif month >= 3 and month <= 5:
    print("Spring")
elif month >= 6 and month <= 8:
    print("Summer")
elif month>=9 and month<=11:
    print("Antumn")
else:
    print("Invalid month number")
# Out:
# Enter the month :  12
# Winter

# %% [markdown]
# ### 5. Accept a float number and check if it has more than two digits after the decimal.

# %%
num = input("Enter a float number")
res = num.split(".")[-1]
count = len(res)
if count == 2:
    print("yes, two digit")
else:
    print("no,  two digit")
# Out:
# Enter a float number 12.90
# yes, two digit

# %% [markdown]
# ### 6.Write a Python program to check whether a number is divisible by 5 and 11 or not.

# %%
num = int(input("Enter a number: "))

if num % 5 == 0 and num % 11 == 0:
    print("Number is divisible by both 5 and 11")
else:
    print("Number is not divisible by both 5 and 11")
# Out:
# Enter a number:  55
# Number is divisible by both 5 and 11

# %% [markdown]
# ### 7. Write a Python program to check whether a year is leap year or not.

# %%
year = int(input("Enter a year: "))
if year % 400 == 0:
    print("leap year")
elif year % 100 == 0:
        print("Not leap year")
elif year % 4 == 0:
        print("leap year")
else:
    print("not leap year")
# Out:
# Enter a year:  2000
# leap year

# %% [markdown]
# ### 8. Write a Python program to check whether a character is alphabet or not.

# %%
alp = input("Enter a  alphabet")
if alp.isalpha():
    print(f"yes, {alp} is a alphabet")
else:
    print(f"No, {alp} is not a alphabet")
# Out:
# Enter a  alphabet A
# yes, A is a alphabet

# %% [markdown]
# ### 9. Write a Python program to input any alphabet and check whether it is vowel or consonant.

# %%
alp =input("Enter a alphabet: ")
if alp in "aeiou":
    print(f" '{alp}' is  alphabet")
else:
      print(f" '{alp}' is not  alphabet")
# Out:
# Enter a alphabet:  c
#  'c' is not  alphabet

# %% [markdown]
# ### 10.Write a Python program to input any character and check whether it is alphabet, digit or special character.

# %%
char = input("Enter a character")
if char.isalpha():
    print(f"{char} is alphabet")
elif char.isdigit():
    print(f"{char} is a digit")
else:
    print(f"{char} is a special charcter")
# Out:
# Enter a character $
# $ is a special charcter

# %% [markdown]
# ### 11. Write a Python program to check whether a character is uppercase or lowercase alphabet.

# %%
char = input("Enter a character")
if char >= 'A' and char<='Z':
    print("It is uppercase")
elif char >= 'a' and char <= 'z':
    print("It is lowercase")
else:
    print("It is not a alphabet")
# Out:
# Enter a character @
# It is not a alphabet

# %% [markdown]
# ### 12. Write a Python program to input week number and print weekday.

# %%
day = int(input("Enter the number: "))
if day<=0 or day>7:
    print("you enter  invalid day")
elif day ==1:
    print("monday")
elif day ==2:
    print("Tuesday")
elif day ==3:
    print("Wedensday")
elif day ==4:
    print("Thursday")
elif day ==5:
    print("friday")
elif day ==6:
    print("saturday")
elif day ==7:
    print("sunday")
# Out:
#  Enter the number  7
# sunday

# %% [markdown]
# ### 13. Write a Python program to input angles of a triangle and check whether triangle is valid or not.

# %%
angle1 = float(input("Enter the value of angle1: "))
angle2 = float(input("Enter the value of angle2: "))
angle3 = float(input("Enter the value of angle3: "))

if angle1 + angle2 + angle3 == 180 and angle1 > 0 and angle2 > 0 and angle3 > 0:
    print("Triangle is valid")
else:
    print("Triangle is not valid")
# Out:
# Enter the value of angle1:  50
# Enter the value of angle2:  50
# Enter the value of angle3:  50
# Triangle is not valid

# %% [markdown]
# ### 14. Write a Python program to input all sides of a triangle and check whether triangle is valid or not.

# %%
side1 = float(input("Enter the value of angle1: "))
side2 = float(input("Enter the value of angle2: "))
side3 = float(input("Enter the value of angle3: "))

if (side1 + side2 > side3) and (side2 +side3 >side1) and angle1 + angle3 > angle2:
    print("Triangle is valid")
else:
    print("Triangle is not valid")
# Out:
# Enter the value of angle1:  20
# Enter the value of angle2:  20
# Enter the value of angle3:  60
# Triangle is not valid

# %% [markdown]
# ### 15. Write a Python program to check whether the triangle is equilateral, isosceles or scalene triangle.

# %%
a = float(input("Enter the first side"))
b = float(input("Enter the second side"))
c = float(input("Enter the third side"))
if (a + b > c) and (b + c > a) and (c + a > b):
    if a == b == c:
        print("The triangle is equilateral")
    elif a==b or b==c or c==a:
        print("The Triangle is isosceles")
    else:
        print("The triangle is scalene")
else:
    print("this is not a triangle")
# Out:
# Enter the first side 5
# Enter the second side 5
# Enter the third side 5
# The triangle is equilateral

# %% [markdown]
# ### 16. Write a Python program to input marks of five subjects Physics, Chemistry, Biology, Mathematics and Computer. Calculate percentage and grade according to following:
#
#   1. Percentage >= 90% : Grade A
#   2. Percentage >= 80% : Grade B
#   3. Percentage >= 70% : Grade C
#   4. Percentage >= 60% : Grade D
#   5. Percentage >= 40% : Grade E
#   6. Percentage < 40% : Grade F

# %%
phy = float(input("Enter marks of physics"))
chem = float(input("Enter marks of chemistry"))
bio = float(input("Enter marks of biology"))
maths = float(input("Enter marks of maths")) 
comp = float(input("Enter marks of computer"))

total_marks = phy + chem + bio + maths + comp
percentage = (total_marks / 500) * 100
if percentage >= 90:
    print("Grade A")
elif percentage >= 80:
    print("Grade B")
elif percentage >= 70:
    print("Grade C")
elif percentage >= 60:
    print("Grade D")
elif percentage >= 40:
    print("Grade E")
else:
    print("Grade F")
# Out:
# Enter marks of physics 23
# Enter marks of chemistry 56
# Enter marks of biology 89
# Enter marks of maths 78
# Enter marks of computer 56
# Grade D

# %% [markdown]
# ### 17. Write a Python program to input basic salary of an employee and calculate its Gross salary according to following:
#
#    1. Basic Salary <= 10000 : HRA = 20%, DA = 80%
#    2. Basic Salary <= 20000 : HRA = 25%, DA = 90%
#    3. Basic Salary > 20000 : HRA = 30%, DA = 95%

# %%
salary = int(input("Enter your salary"))
if salary <= 10000:
    hra = salary * 0.20
    da = salary * 0.80
    print(f"HRA IS {hra}")
    print(f"DA is {da}")

elif salary <= 20000:
    hra = salary * 0.25
    da = salary * 0.90
    print(f"HRA IS {hra}")
    print(f"DA is {da}")

elif salary > 20000:
    hra = salary * 0.30
    da = salary * 0.95
    print(f"HRA IS {hra}")
    print(f"DA is {da}")
# Out:
# Enter your salary 20000
# HRA IS 5000.0
# DA is 18000.0

# %% [markdown]
# ### 18. Write a Python Program to input electricity unit charges and calculate total electricity bill according to the given condition:
#
#    1. For first 50 units Rs. 0.50/unit
#    2. For next 100 units Rs. 0.75/unit
#    3. For next 100 units Rs. 1.20/unit
#    4. For unit above 250 Rs. 1.50/unit
#    5. An additional surcharge of 20% is added to the bill

# %%
units = float(input("Enter the no of unit "))

if units <= 50:
    
    bill = units * 0.50
    
elif units <=150:
    
    bill = 50 * 0.5 + (units-50) * 0.75

elif units <= 250:
    
    bill = 50 * 0.5 + 100 *0.75 + (units-150)*1.20

elif units > 250:

     bill = 50*0.5 + 100*0.75 + 100*1.2 + (units-250)*1.5

surcharge = 0.20 * bill

total_bill=bill+surcharge

print(f"total bill is {total_bill}")
# Out:
# Enter the no of unit  200
# total bill is 192.0
