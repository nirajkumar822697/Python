# %% [markdown]
# # LIST

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
ls = [1,100,900,900,]    # deep copy and shallow copy

# %%
li =["Niraj" , "Manish" ,"vishal" ,"jai" ,"rishi"]

# %%
li[0]
# Out:
# 'Niraj'

# %%
li[-1] = "sachin"

# %%
li
# Out:
# ['Niraj', 'Manish', 'vishal', 'jai', 'sachin']

# %%
li.append("Arya")

# %%
li
# Out:
# ['Niraj', 'Manish', 'vishal', 'jai', 'sachin', 'Arya']

# %%
li.sort()

# %%
li
# Out:
# ['Arya', 'Manish', 'Niraj', 'jai', 'sachin', 'vishal']

# %%
li.sort(reverse=True)

# %%
li
# Out:
# ['vishal', 'sachin', 'jai', 'Niraj', 'Manish', 'Arya']

# %% [markdown]
# # Tuple

# %%
print(dir(tuple))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
Tuple = (1,2,3,4,4,5,5,5,5)

# %%
Tuple.count(5)
# Out:
# 4

# %%
Tuple.index(4)
# Out:
# 3

# %%
len(Tuple)
# Out:
# 9

# %%
print(Tuple[::-1])
# Out:
# (5, 5, 5, 5, 4, 4, 3, 2, 1)

# %%
print(Tuple[2:5:])
# Out:
# (3, 4, 4)

# %%
print(Tuple[::2])
# Out:
# (1, 3, 4, 5, 5)

# %%
tp = ("Niraj" ,"Manish", "Jay")

# %%
tp[0]
# Out:
# 'Niraj'

# %%
tp[::-1]
# Out:
# ('Jay', 'Manish', 'Niraj')

# %%
tp.count("Manish")
# Out:
# 1

# %%
print(type(tp))
# Out:
# <class 'tuple'>

# %% [markdown]
# # Dictionary

# %%
Dict = {
"name" :"niraj",
"roll no" :814,
"section" :"C"
}

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
d = {}
print(type(d))
print(d)
# Out:
# <class 'dict'>
# {}

# %%
print(Dict)
# Out:
# {'name': 'niraj', 'roll no': 814, 'section': 'C'}

# %%
data = {
    "Name" : "Manish",
    "from" :"jharkhand",
    "salary" : 500000
}

# %%
data
# Out:
# {'Name': 'Manish', 'from': 'jharkhand', 'salary': 500000}

# %%
data1 = {
    "Name" : "Niraj",
    "from" :"jharkhand",
    "salary" : 500000,

}

# %%
data
# Out:
# {'Name': 'Manish', 'from': 'jharkhand', 'salary': 500000}

# %%
data["Name"]
# Out:
# 'Manish'

# %%
data["salary"]
# Out:
# 500000

# %%
data["Name"]
# Out:
# 'Manish'

# %%
data
# Out:
# {'Name': 'Manish', 'from': 'jharkhand', 'salary': 500000}

# %%
data.keys() # return all the keys from the dictionary
# Out:
# dict_keys(['Name', 'from', 'salary'])

# %%
data.items() # return all the both from the dictionary
# Out:
# dict_items([('Name', 'Manish'), ('from', 'jharkhand'), ('salary', 500000)])

# %%
data.values() # return all the values from the dictionary
# Out:
# dict_values(['Manish', 'jharkhand', 500000])

# %%
data.get("Name")
# Out:
# 'Manish'

# %%
data.get("Na","Not Found....")
# Out:
# 'Not Found....'

# %%
data.pop("salary")
# Out:
# 500000

# %%
data.popitem()
# Out:
# ('from', 'jharkhand')

# %%
data
# Out:
# {'Name': 'Manish'}

# %%
data1 = {
    "Name" : "Manish",
    "from" :"jharkhand",
    "salary" : 500000,
    "age" : 24
  
}

# %%
data1
# Out:
# {'Name': 'Niraj', 'from': 'jharkhand', 'salary': 500000}

# %%
data1.update(data)

# %%
data1
# Out:
# {'Name': 'Manish', 'from': 'jharkhand', 'salary': 500000}

# %%
a=data1.copy()

# %%
a
# Out:
# {'Name': 'Manish', 'from': 'jharkhand', 'salary': 500000}

# %%
a.clear()

# %%
a
# Out:
# {}

# %%
data
# Out:
# {'Name': 'Manish'}

# %%
data.update({"Country":"India"})

# %%
data
# Out:
# {'Name': 'Manish', 'Country': 'India'}

# %%
a=
bool(a)
# Out:
# True

# %%
data = {'coord': {'lon': 75.8167, 'lat': 26.9167},
 'weather': [{'id': 721,
   'main': 'Haze',
   'description': 'haze',
   'icon': '50d'}],
 'base': 'stations',
 'main': {'temp': 23.62,
  'feels_like': 22.69,
  'temp_min': 23.62,
  'temp_max': 23.62,
  'pressure': 1015,
  'humidity': 25,
  'sea_level': 1015,
  'grnd_level': 967},
 'visibility': 4000,
 'wind': {'speed': 1.03, 'deg': 0},
 'clouds': {'all': 0},
 'dt': 1768471847,
 'sys': {'type': 1,
  'id': 9170,
  'country': 'IN',
  'sunrise': 1768441625,
  'sunset': 1768479869},
 'timezone': 19800,
 'id': 1269515,
 'name': 'Jaipur',
 'cod': 200}

# %%
data
# Out:
# {'coord': {'lon': 75.8167, 'lat': 26.9167},
#  'weather': [{'id': 721,
#    'main': 'Haze',
#    'description': 'haze',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 23.62,
#   'feels_like': 22.69,
#   'temp_min': 23.62,
#   'temp_max': 23.62,
#   'pressure': 1015,
#   'humidity': 25,
#   'sea_level': 1015,
#   'grnd_level': 967},
#  'visibility': 4000,
#  'wind': {'speed': 1.03, 'deg': 0},
#  'clouds': {'all': 0},
#  'dt': 1768471847,
#  'sys': {'type': 1,
#   'id': 9170,
#   'country': 'IN',
#   'sunrise': 1768441625,
#   'sunset': 1768479869},
#  'timezone': 19800,
#  'id': 1269515,
#  'name': 'Jaipur',
#  'cod': 200}

# %% [markdown]
# # ***find out  these items***
# 1. name
# 2. temp_Max
# 3. temp_min
# 4. wind speed
# 5. main
# 6. humidity
# 7. sunrise

# %%
data.keys()
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
data['weather']
# Out:
# [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}]

# %%
data["name"]  # Name
# Out:
# 'Jaipur'

# %%
data["main"]   # Main
# Out:
# {'temp': 23.62,
#  'feels_like': 22.69,
#  'temp_min': 23.62,
#  'temp_max': 23.62,
#  'pressure': 1015,
#  'humidity': 25,
#  'sea_level': 1015,
#  'grnd_level': 967}

# %%
data["main"]["temp_min"] # Temp_min
# Out:
# 23.62

# %%
data["main"]["temp_max"] # Temp_max
# Out:
# 23.62

# %%
data["wind"]["speed"]   # wind speed
# Out:
# 1.03

# %%
data["main"]["humidity"]  # Humidity
# Out:
# 25

# %%
data["sys"]
# Out:
# {'type': 1,
#  'id': 9170,
#  'country': 'IN',
#  'sunrise': 1768441625,
#  'sunset': 1768479869}

# %%
data["sys"]["sunrise"]   #sunrise
# Out:
# 1768441625
